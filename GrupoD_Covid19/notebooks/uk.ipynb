# %%
import numpy as np 
import pandas as pd 
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
world = pd.read_csv("file:///C:/Users/javig/AppData/Local/Temp/owid-covid-data.csv")
uk = world[world["iso_code"]=="GBR"]
port = world[world["iso_code"]=="PRT"]
ven = world[world["iso_code"]=="VEN"]
turk = world[world["iso_code"]=="TUR"]
esp = world[world["iso_code"]=="ESP"]
world.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred',
# ...

# %%
uk = uk.drop(uk.columns.difference(["iso_code","date",'total_cases',"total_deaths", 'total_deaths_per_million']), 1)
port = port.drop(port.columns.difference(["iso_code","date",'total_cases',"total_deaths", 'total_deaths_per_million']), 1)
ven = ven.drop(ven.columns.difference(["iso_code","date",'total_cases',"total_deaths", 'total_deaths_per_million']), 1)
turk = turk.drop(turk.columns.difference(["iso_code","date",'total_cases',"total_deaths", 'total_deaths_per_million']), 1)
esp = esp.drop(esp.columns.difference(["iso_code","date",'total_cases',"total_deaths", 'total_deaths_per_million']), 1)

# %%
uk
# Out:
#       iso_code        date  total_cases  total_deaths  \
# 57229      GBR  2020-01-31          2.0           NaN
# 57230      GBR  2020-02-01          2.0           NaN
# 57231      GBR  2020-02-02          2.0           NaN
# 57232      GBR  2020-02-03          8.0           NaN
# 57233      GBR  2020-02-04          8.0           NaN
# ...        ...         ...          ...           ...
# 57578      GBR  2021-01-14    3269757.0       86163.0
# 57579      GBR  2021-01-15    3325642.0       87448.0
# 57580      GBR  2021-01-16    3367070.0       88747.0
# 57581      GBR  2021-01-17    3405740.0       89429.0
# 57582      GBR  2021-01-18    3443350.0       90031.0
#
#        total_deaths_per_million
# 57229                       NaN
# 57230                       NaN
# 57231                       NaN
# 57232                       NaN
# 57233                       NaN
# ...                         ...
# 57578                  1269.231
# 57579                  1288.159
# ...

# %%
uk.dropna( inplace= True)
port.dropna( inplace= True)
ven.dropna( inplace= True)
turk.dropna( inplace= True)
esp.dropna( inplace= True)

# %%
print(uk.corr())
port.corr()
ven.corr()
turk.corr()
esp.corr()
# Out:
#                           total_cases  total_deaths  total_deaths_per_million
# total_cases                  1.000000      0.847452                  0.847452
# total_deaths                 0.847452      1.000000                  1.000000
# total_deaths_per_million     0.847452      1.000000                  1.000000
#                           total_cases  total_deaths  total_deaths_per_million
# total_cases                  1.000000      0.871619                  0.871619
# total_deaths                 0.871619      1.000000                  1.000000
# total_deaths_per_million     0.871619      1.000000                  1.000000

# %%
sns.heatmap(uk.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(port.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(ven.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(turk.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(esp.corr())
# Out:
# <AxesSubplot:>

# %%
import plotly.express as px

# %%
uk_graph= uk.drop(uk.columns.difference(["date",'total_cases',"total_deaths"]), 1)
port_graph= port.drop(port.columns.difference(["date",'total_cases',"total_deaths"]), 1)
ven_graph=ven.drop(ven.columns.difference(["date",'total_cases',"total_deaths"]), 1)
turk_graph=turk.drop(turk.columns.difference(["date",'total_cases',"total_deaths"]), 1)
esp_graph=esp.drop(esp.columns.difference(["date",'total_cases',"total_deaths"]), 1)

# %%
fig=px.line(uk_graph, x= uk_graph['date'], y=uk_graph.columns, title= ' UK covid deaths')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()

# %%
fig=px.line(port_graph, x= port_graph['date'], y=port_graph.columns, title= 'Portugal covid deaths')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()

# %%
fig=px.line(ven_graph, x= ven_graph['date'], y=ven_graph.columns, title= 'Venezuela covid deaths')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()

# %%
fig=px.line(turk_graph, x= turk_graph['date'], y=turk_graph.columns, title= 'Turkey covid deaths')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()

# %%
fig=px.line(esp_graph, x= esp_graph['date'], y=esp_graph.columns, title= 'Turkey covid deaths')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig.show()

# %%
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(uk_graph["total_cases"])
pyplot.show()

# %%
fig = px.scatter(uk_graph, x=uk_graph["date"], y=uk_graph.columns, title="Uk covid point")
fig.show()

# %%
fig = px.scatter(port_graph, x=port_graph["date"], y=port_graph.columns, title="Portugal covid point")
fig.show()

# %%
fig = px.scatter(ven_graph, x=ven_graph["date"], y=ven_graph.columns, title="Venezuela covid point")
fig.show()

# %%
fig = px.scatter(turk_graph, x=turk_graph["date"], y=turk_graph.columns, title="Turkey covid point")
fig.show()

# %%
fig = px.scatter(esp_graph, x=esp_graph["date"], y=esp_graph.columns, title="Spain covid point")
fig.show()

# %%
x = uk["date"]
plt.bar(x, uk["total_cases"], color='b', width= 0.25)
plt.bar(x, uk["total_deaths"], color='g', width= 0.25)
plt.show()
