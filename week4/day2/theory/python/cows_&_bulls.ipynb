# %% [markdown]
# - [Cows_and_Bulls]
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#
#   >Enter a number:
#
#   >> 1234
#
#   >>> 2 cows, 0 bulls
#
#   >> 1253
#
#   >>> 1 cow, 1 bull
#
#   ...
# Until the user guesses the number or write "STOP"

# %%
# intento 3
x = int(input("digit number1:"))
y = int (input("solution"))
cows = 0
bulls = 0
def cows_bulls(x,y):
    for z in x
        for q in y
            if val[x] ==val[y] and pos[x]==pos[y]:
                cows+=1
            if val[x]== val[y]:
                bulls+=1
        return cows , bulls

# %%
import random

def cows_bulls_games(num_digits):
    # tenemos que generar una lista aleatoria de 4 numeros 
    list_num = [random.randint(0, 9) for n in range(num_digits)]
    print("The solution is:", list_num)

    
    acum = 0 
    while True:
        # aqui vemos el numero de intentos que lleva
        acum+=1
        print("try:", acum)
        guess_num = [int(i) for i in input("guess the number:")]

        # esto es para ver si ha dado en el clavo
        if guess_num == list_num:
            print("YOU WIN")
            print("it took you:", acum, "tries")
            break

        else:
            # tenemos que ver cuanto ha acertado
            cows = 0
            bulls = 0
            
            for x in range (0,num_digits):
                if guess_num[x] == list_num[x]: #number and position are right
                    cows+=1
                elif guess_num[x] in list_num: # number is in the list but not in position
                    bulls +=1
        print("cows:", cows, "bulls:", bulls)
        print("-------------------------------")
cows_bulls_games(4)
# Out:
# The solution is: [7, 0, 4, 0]
# try: 1
# cows: 2 bulls: 0
# -------------------------------
# try: 2
# cows: 0 bulls: 1
# -------------------------------
# try: 3
# YOU WIN
#  it took you: 3 tries
